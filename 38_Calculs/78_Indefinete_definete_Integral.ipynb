# %%
import sympy as sym
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Math
from scipy.signal import find_peaks
from sympy.abc import x,y

# %%
x = sym.symbols('x')
f = x 
sym.integrate(f)
p = sym.plotting.plot(f,show=False)
p.xlim = [0,1]
p.ylim =[0,1]
p.show()

# %%
sym.diff(f)
# Out:
# 1

# %%
sym.integrate(f,(x,0,1))
# Out:
# 1/2

# %%
f = x**3 / (x-2)
intf = sym.integrate(f)
p = sym.plotting.plot(f,show=False)
p.extend(sym.plotting.plot(intf,(x,2.1,10),show=False, line_color='r'))
p[0].label = '$f(x) = %s$' %(sym.latex(f))
p[1].label = '$\\int f(x) dx = %s$' %(sym.latex(intf))

p.ylim =[-200,200]
p.legend = True
p.show()

# %%
x = sym.symbols('x')
f = 2*x**3  + sym.sin(x)
df = sym.diff(f)
idf = sym.integrate(df)
display(Math('f(x) = %s' %sym.latex(f)))
display(Math('f\' = %s' %sym.latex(df)))
display(Math('\\int f\' = %s' %sym.latex(idf)))
# Out:
# $$f(x) = 2 x^{3} + \sin{\left (x \right )}$$
# $$f' = 6 x^{2} + \cos{\left (x \right )}$$
# $$\int f' = 2 x^{3} + \sin{\left (x \right )}$$
