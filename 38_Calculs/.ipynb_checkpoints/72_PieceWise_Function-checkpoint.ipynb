# %%
import sympy as sym
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Math

# %%
from sympy.abc import x
piece1 = 0
piece2 = -2*x
piece3 = x**3/10

fx = sym.Piecewise((piece1, x<0),(piece2,((x>=0)& (x<10))),(piece3,x>=10))

# %%
fx
# Out:
# Piecewise((0, x < 0), (-2*x, (x >= 0) & (x < 10)), (x**3/10, x >= 10))

# %%
fxx = sym.lambdify(x,fx)
xx = np.linspace(-3,15,1234)
plt.plot(xx,fxx(xx))

# %%
f1 = x**3
f2 = sym.log(x,2)

fx =  sym.Piecewise((f1, x<=0),(f2,x>0))
fx
# Out:
# Piecewise((x**3, x <= 0), (log(x)/log(2), x > 0))

# %%
display(Math('f(x) = ' + sym.latex(fx)))
# Out:
# $$f(x) = \begin{cases} x^{3} & \text{for}\: x \leq 0 \\\frac{\log{\left (x \right )}}{\log{\left (2 \right )}} & \text{for}\: x > 0 \end{cases}$$

# %%
fxx =  sym.lambdify(x,fx)
with plt.xkcd():
    plt.plot(xx, fxx(xx),'k')
# Out:
# C:\ProgramData\Anaconda3\envs\learnMath\lib\site-packages\numpy\__init__.py:1: RuntimeWarning: invalid value encountered in log
#   """
