# %%
import numpy as np
import sympy as sym
from IPython.display import display,Math
import scipy as sp
import matplotlib.pyplot as plt

# %%
lst = [-4,5.5,1,2]
maxval = np.max(lst)

# %%
maxvalidx = np.argmax(lst)

# %%
lst[maxvalidx]
# Out:
# 5.5

# %%
x = np.linspace(0,2*np.pi,20)
fx = -(np.cos(x) + np.sqrt(x))
fmax = np.max(fx)
famxidx = np.argmax(fx)
plt.plot(x,fx,'bo-')
plt.plot(x[famxidx],fmax, 'rs')
plt.show()

# %%
x = np.linspace(-2,2,51)
fx = x**3 + x**4
fminidx = np.argmin(fx)

plt.plot(x,fx,'bs-')
plt.plot(x[fminidx],fx[fminidx],'rs')
plt.xlim([-1.2,0.5])
plt.ylim([-.12,-.1])
plt.show()

# %%
from scipy.signal import find_peaks
x = np.linspace(0,12*np.pi,213)
fx = -np.cos(x) - np.sqrt(x)

peaks = find_peaks(fx)
plt.plot(x,fx)
plt.plot(x[peaks[0]],fx[peaks[0]],'o')
plt.show()
