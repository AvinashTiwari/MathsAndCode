# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
shift = 5
stretch = 2
n =1000

#pnts = np.random.randn(n)*stretch +shift
pnts = np.random.randn(n)*stretch
print('Mean is %g, std %g' %(np.mean(pnts), np.std(pnts)))
# Out:
# Mean is 0.0336606, std 1.93494

# %%
fig , ax = plt.subplots(1,2, figsize=(6,4))
ax[0].plot(pnts,'s', alpha=.4)
ax[1].hist(pnts, 1000)
plt.show()

# %%
from scipy.stats import rankdata

# %%
n =500
orig_data= 2**np.random.rand(n)
rank_data = rankdata(orig_data)
norm_data = 2*(rank_data/np.max(rank_data)) - 1
ran_data1 = np.append(rank_data, np.max(rank_data) + 1)
trans_data = np.arctanh(ran_data1)
# Out:
# C:\ProgramData\Anaconda3\envs\learnMath\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in arctanh
#
# C:\ProgramData\Anaconda3\envs\learnMath\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in arctanh

# %%
fig, ax = plt.subplots(1,3)
ax[0].hist(orig_data,30)
ax[0].set_xlabel('Value')
ax[0].set_ylabel('Count')

ax[1].hist(rank_data,30)
ax[1].set_xlabel('Value')
ax[1].set_ylabel('Count')


ax[2].hist(norm_data,30)
ax[2].set_xlabel('Value')
ax[2].set_ylabel('Count')
# Out:
# Text(0,0.5,'Count')
