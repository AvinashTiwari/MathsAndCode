# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 10*np.pi, 1234)
k = -3
x = np.cos(t) * np.exp(t/k)
y = np.sin(t) * np.exp(t/k)

plt.plot(x,y,'k', linewidth=2)
#plt.plot(x,-y,'k', linewidth=2)

plt.axis('square')
plt.axis('off')
# Out:
# (-0.4391166238901111, 1.0685293630423862, -0.261787548456517, 1.24585843847598)

# %%
N = 150
ks = np.linspace(-6, -2, N)

for i in range(N):
    x = np.cos(t) * np.exp(t/ks[i])
    y = np.sin(t) * np.exp(t/ks[i])

    plt.plot(x,y,color=[i/N,i/N,0])
#plt.plot(x,-y,'k', linewidth=2)

plt.axis('square')
plt.axis('off')
# Out:
# (-0.6806562554802219,
#  1.080031250260963,
#  -0.5243827276223232,
#  1.2363047781188616)
